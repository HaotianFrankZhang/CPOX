# %%
import MDAnalysis as mda
from MDAnalysis.analysis.rms import RMSD
from prody import *
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from numpy import *

import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Eval distances function

# %%
def calcDistancesK220(numbers, currDirectory):
    distances = []
    for currNumber in numbers:
        structure = parsePDB(currDirectory + 'frame_' + currNumber + '.pdb')

        # Select the alpha carbon atoms of the specified residues
        ca1 = structure.select('resid 112 and name CA')

        # Ensure the selections are not empty
        distance = calcDistance(ca1[0], ca1[1])
        distances.append(distance)
    return distances

def calcDistancesF408(numbers, currDirectory):
    distances = []
    for currNumber in numbers:
        structure = parsePDB(currDirectory + 'frame_' + currNumber + '.pdb')

        # Select the alpha carbon atoms of the specified residues
        ca1 = structure.select('resid 300 and name CA')

        # Ensure the selections are not empty
        distance = calcDistance(ca1[0], ca1[1])
        distances.append(distance)
    return distances

def calcDistances262_408(numbers, currDirectory):
    distances_A = []
    distances_B = []
    for currNumber in numbers:
        structure = parsePDB(currDirectory + 'frame_' + currNumber + '.pdb')
        # Select the alpha carbon atoms of the specified residues
        ca1 = structure.select('resid 300 and name CA')
        ca2 = structure.select('resid 154 and name CA')

        # Ensure the selections are not empty
        distance_A = calcDistance(ca1[0], ca2[0])
        distance_B = calcDistance(ca1[1], ca2[1])
        distances_A.append(distance_A)
        distances_B.append(distance_B)
    return distances_A, distances_B

def calcDistances408_185(numbers, currDirectory):
    distances_A = []
    distances_B = []
    for currNumber in numbers:
        structure = parsePDB(currDirectory + 'frame_' + currNumber + '.pdb')
        # Select the alpha carbon atoms of the specified residues
        ca1 = structure.select('resid 300 and name CA')
        ca2 = structure.select('resid 77 and name CA')

        # Ensure the selections are not empty
        distance_A = calcDistance(ca1[0], ca2[0])
        distance_B = calcDistance(ca1[1], ca2[1])
        distances_A.append(distance_A)
        distances_B.append(distance_B)
    return distances_A, distances_B

def calcDistances408_341(numbers, currDirectory):
    distances_A = []
    distances_B = []
    for currNumber in numbers:
        structure = parsePDB(currDirectory + 'frame_' + currNumber + '.pdb')
        # Select the alpha carbon atoms of the specified residues
        ca1 = structure.select('resid 300 and name CA')
        ca2 = structure.select('resid 233 and name CA')

        # Ensure the selections are not empty
        distance_A = calcDistance(ca1[0], ca2[0])
        distance_B = calcDistance(ca1[1], ca2[1])
        distances_A.append(distance_A)
        distances_B.append(distance_B)
    return distances_A, distances_B

def calcDistances405_221(numbers, currDirectory):
    distances_A = []
    distances_B = []
    for currNumber in numbers:
        structure = parsePDB(currDirectory + 'frame_' + currNumber + '.pdb')
        # Select the alpha carbon atoms of the specified residues
        ca1 = structure.select('resid 297 and name CA')
        ca2 = structure.select('resid 113 and name CA')

        # Ensure the selections are not empty
        distance_A = calcDistance(ca1[0], ca2[0])
        distance_B = calcDistance(ca1[1], ca2[1])
        distances_A.append(distance_A)
        distances_B.append(distance_B)
    return distances_A, distances_B

def calcDistances135_188(numbers, currDirectory):
    distances_A = []
    distances_B = []
    for currNumber in numbers:
        structure = parsePDB(currDirectory + 'frame_' + currNumber + '.pdb')
        # Select the alpha carbon atoms of the specified residues
        ca1 = structure.select('resid 27 and name CA')
        ca2 = structure.select('resid 80 and name CA')

        # Ensure the selections are not empty
        distance_A = calcDistance(ca1[0], ca2[0])
        distance_B = calcDistance(ca1[1], ca2[1])
        distances_A.append(distance_A)
        distances_B.append(distance_B)
    return distances_A, distances_B

# %%
def calcDistances206_416(numbers, currDirectory):
    distances_A = []
    distances_B = []
    for currNumber in numbers:
        structure = parsePDB(currDirectory + 'frame_' + currNumber + '.pdb')
        # Select the alpha carbon atoms of the specified residues
        ca1 = structure.select('resid 98 and name CA')
        ca2 = structure.select('resid 308 and name CA')

        # Ensure the selections are not empty
        distance_A = calcDistance(ca1[0], ca2[0])
        distance_B = calcDistance(ca1[1], ca2[1])
        distances_A.append(distance_A)
        distances_B.append(distance_B)
    return distances_A, distances_B

def calcDistances340_409(numbers, currDirectory):
    distances_A = []
    distances_B = []
    for currNumber in numbers:
        structure = parsePDB(currDirectory + 'frame_' + currNumber + '.pdb')
        # Select the alpha carbon atoms of the specified residues
        ca1 = structure.select('resid 232 and name CA')
        ca2 = structure.select('resid 301 and name CA')

        # Ensure the selections are not empty
        distance_A = calcDistance(ca1[0], ca2[0])
        distance_B = calcDistance(ca1[1], ca2[1])
        distances_A.append(distance_A)
        distances_B.append(distance_B)
    return distances_A, distances_B

# *************************************************************************************************
# *********************************** new distances ************************************************
def calcDistancesloop2_Bsheet(numbers, currDirectory):
    distances_A = []
    distances_B = []
    for currNumber in numbers:
        structure = parsePDB(currDirectory + 'frame_' + currNumber + '.pdb')
        # Select the alpha carbon atoms of the specified residues
        ca1 = structure.select('resid 134 and name CA')
        ca2 = structure.select('resid 294 and name CA')

        # Ensure the selections are not empty
        distance_A = calcDistance(ca1[0], ca2[0])
        distance_B = calcDistance(ca1[1], ca2[1])
        distances_A.append(distance_A)
        distances_B.append(distance_B)
    return distances_A, distances_B

def calcDistancesloop2_lid(numbers, currDirectory):
    distances_A = []
    distances_B = []
    for currNumber in numbers:
        structure = parsePDB(currDirectory + 'frame_' + currNumber + '.pdb')
        # Select the alpha carbon atoms of the specified residues
        ca1 = structure.select('resid 113 and name CA')
        ca2 = structure.select('resid 294 and name CA')

        # Ensure the selections are not empty
        distance_A = calcDistance(ca1[0], ca2[0])
        distance_B = calcDistance(ca1[1], ca2[1])
        distances_A.append(distance_A)
        distances_B.append(distance_B)
    return distances_A, distances_B

def calcDistancesloop2_loop3(numbers, currDirectory):
    distances_A = []
    distances_B = []
    for currNumber in numbers:
        structure = parsePDB(currDirectory + 'frame_' + currNumber + '.pdb')
        # Select the alpha carbon atoms of the specified residues
        ca1 = structure.select('resid 232 and name OD2')
        ca2 = structure.select('resid 293 and name NH2')

        # Ensure the selections are not empty
        distance_A = calcDistance(ca1[0], ca2[0])
        distance_B = calcDistance(ca1[1], ca2[1])
        distances_A.append(distance_A)
        distances_B.append(distance_B)
    return distances_A, distances_B

def calcDistancesloop1_loop2(numbers, currDirectory):
    distances_A = []
    distances_B = []
    for currNumber in numbers:
        structure = parsePDB(currDirectory + 'frame_' + currNumber + '.pdb')
        # Select the alpha carbon atoms of the specified residues
        ca1 = structure.select('resid 73 and name NE1')
        ca2 = structure.select('resid 305 and name NE')

        # Ensure the selections are not empty
        distance_A = calcDistance(ca1[0], ca2[0])
        distance_B = calcDistance(ca1[1], ca2[1])
        distances_A.append(distance_A)
        distances_B.append(distance_B)
    return distances_A, distances_B

# %% [markdown]
# ## Calculate distances

# %%
# all distances
# mutations = ['G188Q', 'L155W', 'V135A', 'WT']
mutations = ['N272H_AF', 'WT_AF']
Runs = ['Run1', 'Run2']

frames = ["{:04}".format(i) for i in range(1, 2001)]

# %%
allDistance = {}
for currMutation in mutations:
    if currMutation not in allDistance:
        allDistance[currMutation] = {}
    
    for currRuns in Runs:
        currRun = currRuns + '_frame'
        if currRuns not in allDistance[currMutation].keys():
            allDistance[currMutation][currRuns] = {}
            
        currDirectory = './' + currMutation + '/' + currRun + '/'

        dist_134_294_1, dist_134_294_2 = calcDistancesloop2_Bsheet(frames, currDirectory)
        dist_113_294_1, dist_113_294_2 = calcDistancesloop2_lid(frames, currDirectory)
        dist_232_293_1, dist_232_293_2 = calcDistancesloop2_loop3(frames, currDirectory)
        dist_73_305_1, dist_73_305_2 = calcDistancesloop1_loop2(frames, currDirectory)
        
        allDistance[currMutation][currRuns]['134_294'] = {'1': dist_134_294_1, '2':dist_134_294_2}
        allDistance[currMutation][currRuns]['113_294'] = {'1': dist_113_294_1, '2':dist_113_294_2}
        allDistance[currMutation][currRuns]['232_293'] = {'1': dist_232_293_1, '2':dist_232_293_2}
        allDistance[currMutation][currRuns]['73_305'] = {'1': dist_73_305_1, '2':dist_73_305_2}
# Out:
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.20s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.21s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.18s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.19s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.17s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.16s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# @> 10928 atoms and 1 coordinate set(s) were parsed in 0.15s.
# ...
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.
# @> 10922 atoms and 1 coordinate set(s) were parsed in 0.13s.

# %%
len(allDistance['WT_AF']['Run2']['134_294']['2'])
# Out:
# 2000

# %%
currChain = '2'
chainNum = 'A' if currChain == '1' else 'B'
print (chainNum, currChain)
# Out:
# B 2

# %%
data = allDistance

# Prepare DataFrame columns and data
columns = []
data_lists = []

# Process data
for mutation in data:
    for run in data[mutation]:
        for dist_key, chains in data[mutation][run].items():
            for chain_id, values in chains.items():
                col_name = f"{mutation}_{run}_{dist_key}_{chain_id}"
                columns.append(col_name)
                data_lists.append(values)  # Append the whole list, not extend

# Create DataFrame from the lists
df = pd.DataFrame(list(zip(*data_lists)), columns=columns)

# Write to Excel file
df.to_excel("AF_distances_new.xlsx", engine='openpyxl', index=False)

# %% [markdown]
# ## Plots

# %%
currKey = '134_294' # '134_294', '134_113', '232_293', '73_305'
title = "Distances between loop1 (W73) and β sheet (R305)" # β 
fileName = "loop2-Bsheet"

data = {}
for mutate in allDistance.keys():
    list1 = allDistance[mutate]['Run1'][currKey]['1']
    list2 = allDistance[mutate]['Run2'][currKey]['1']
    # list3 = allDistance[mutate]['Run1'][currKey]['2']
    # list4 = allDistance[mutate]['Run2'][currKey]['2']
    
    # Zip the lists together
    # zipped_lists = zip(list1, list2, list3, list4)
    zipped_lists = zip(list1, list2)
    
    # Calculate the average of each group of elements
    average_list = [sum(items) / len(items) for items in zipped_lists]
        
    data[mutate.split('_')[0] + ' (AF)'] = average_list

data.keys()
# Out:
# dict_keys(['N272H (AF)', 'WT (AF)'])

# %%
# Colors
colors = ['dodgerblue', 'crimson', 'chartreuse', 'lightgrey']

plt.figure(figsize=(16, 6))

# Increase font sizes
plt.rc('xtick', labelsize=25)
plt.rc('ytick', labelsize=25)
plt.rcParams.update({'font.size': 30})

for (series, values), color in zip(data.items(), colors):
    plt.plot(values, label=series, color=color)


plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), shadow=True, ncol=4)
plt.title(title)
plt.xlabel('Frames')
plt.ylabel('Distance (Å)')
plt.savefig(fileName + '.png', dpi=600)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Colors
colors = ['dodgerblue', 'crimson', 'chartreuse', 'lightgrey'] 
# Create a DataFrame for easier manipulation
df = pd.DataFrame(data)

# Set up the figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6), gridspec_kw={'width_ratios': [5, 1]})

# Increase font sizes
plt.rc('xtick', labelsize=25)
plt.rc('ytick', labelsize=25)
plt.rcParams.update({'font.size': 30})

# First subplot for the line plots
for (series, values), color in zip(df.items(), colors):
    ax1.plot(values, label=series, color=color)

ax1.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), shadow=True, ncol=4)
ax1.set_title(title)
ax1.set_xlabel('Frames')
ax1.set_ylabel('Distance (Å)')

# Second subplot for the distribution plot
for (series, values), color in zip(df.items(), colors):
    sns.kdeplot(values, ax=ax2, vertical=True, color=color, bw_adjust=0.2)

ax2.set_xlabel('Frequency')

# Correct the axis inversion and remove extra labels
# ax2.set_xlim(ax2.get_xlim()[::-1])  # Reversing x-axis to have 0 to max frequency
ax2.set_ylabel('')  # Removing y-axis label

# Save the entire figure
plt.tight_layout()  # Adjust subplots to fit into figure area.
plt.savefig(fileName + '_2.png', dpi=800)
# Out:
# /tmp/ipykernel_3905790/2428987456.py:30: UserWarning:
#
# The `vertical` parameter is deprecated; assigning data to `y`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(values, ax=ax2, vertical=True, color=color, bw_adjust=0.2)
# /tmp/ipykernel_3905790/2428987456.py:30: UserWarning:
#
# The `vertical` parameter is deprecated; assigning data to `y`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(values, ax=ax2, vertical=True, color=color, bw_adjust=0.2)

# %% [markdown]
# ## Pocket information

# %%
def parse_features(file_path):
    features = {}
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.strip().split('\t')
            if parts[0] != 'frame':
                frame_pocket = (int(parts[0].split('_')[1]), parts[1].strip())  # Tuple of (frame, pocket)
                # Extracting features as a dict
                feature_values = dict(part.split(': ') for part in parts[2:])
                features[frame_pocket] = feature_values
    return features

# Parse the file containing the pockets of interest
def parse_pockets_of_interest(file_path):
    pockets_of_interest = {}
    countList = {}
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.strip().split('\t')
            frame = parts[0]
            pocket = parts[1]
            ratio = parts[2].split(',')
            if frame != 'frame':
                pockets_of_interest[int(frame.split('_')[1])] = pocket
                countList[int(frame.split('_')[1])] = [float(x) for x in ratio]
    return pockets_of_interest, countList

# %%
def extractFeatures(features, pockets_of_interest, cutoff_count):
    frames = sorted(pockets_of_interest.keys(), key=lambda x: int(x))  # Sort frames by number
    volumes = [float(features[(frame, pockets_of_interest[frame])]['Volume']) for frame in frames if
                   (frame, pockets_of_interest[frame]) in features]

    volumes_normalize = [float(features[(frame, pockets_of_interest[frame])]['Volume']) \
                         * (cutoff_count[frame][0]/cutoff_count[frame][1]) \
                         for frame in frames if
                   (frame, pockets_of_interest[frame]) in features]


    TotalSASA = [float(features[(frame, pockets_of_interest[frame])]['Total SASA']) for frame in frames if
                   (frame, pockets_of_interest[frame]) in features]
    # plotGram(TotalSASA, frames, 'SASA')

    HydroDensity = [float(features[(frame, pockets_of_interest[frame])]['Mean local hydrophobic density']) for frame in frames if
                     (frame, pockets_of_interest[frame]) in features]

    PolarSASA = [float(features[(frame, pockets_of_interest[frame])]['Polar SASA']) for frame in frames if
                         (frame, pockets_of_interest[frame]) in features]
    # plotGram(PolarSASA, frames, 'Polar SASA')

    charge = [float(features[(frame, pockets_of_interest[frame])]['Charge score']) for frame in frames if
                             (frame, pockets_of_interest[frame]) in features]
    
    return volumes, volumes_normalize, TotalSASA, PolarSASA, HydroDensity, charge

def evalResults(chain1_features_ratio, features, pockets_ratio, cutoff_ratio):
    volumes, volumes_normalize, TotalSASA, PolarSASA, HydroDensity, charge = \
    extractFeatures(features, pockets_ratio, cutoff_ratio)
    chain1_features_ratio[currMutation][run]['Volumes'] = volumes
    chain1_features_ratio[currMutation][run]['Volumes_normalize'] = volumes_normalize
    chain1_features_ratio[currMutation][run]['TotalSASA'] = TotalSASA
    chain1_features_ratio[currMutation][run]['PolarSASA'] = PolarSASA
    chain1_features_ratio[currMutation][run]['HydroDensity'] = HydroDensity
    chain1_features_ratio[currMutation][run]['Charge'] = charge
    return chain1_features_ratio

# %%
chain1_features_ratio = {}
chain2_features_ratio = {}
chain1_features_count = {}
chain2_features_count = {}


for currMutation in mutations:
    if currMutation not in chain1_features_ratio:
        chain1_features_ratio[currMutation] = {}
    if currMutation not in chain2_features_ratio:
        chain2_features_ratio[currMutation] = {}
    if currMutation not in chain1_features_count:
        chain1_features_count[currMutation] = {}
    if currMutation not in chain2_features_count:
        chain2_features_count[currMutation] = {}
    
    for run in Runs:
        if run not in chain1_features_ratio[currMutation]:
            chain1_features_ratio[currMutation][run] = {}
        if run not in chain2_features_ratio[currMutation]:
            chain2_features_ratio[currMutation][run] = {}
        if run not in chain1_features_count[currMutation]:
            chain1_features_count[currMutation][run] = {}
        if run not in chain2_features_count[currMutation]:
            chain2_features_count[currMutation][run] = {}
            
        features_file = './' + currMutation + '/' + run + '_Features.txt'
        pockets_of_interest_file = './' + currMutation + '/fpocketResults/' + run + '_chain1.txt'
        pockets_ratio_file = './' + currMutation + '/fpocketResults/Ratio_' + run + '_chain1.txt'

        # Parsing files
        features = parse_features(features_file) # {(frame, pocket): {scores: 'numbers'}}
        pockets_count, cutoff_count = parse_pockets_of_interest(pockets_of_interest_file) # {#frame: pocket}
        pockets_ratio, cutoff_ratio = parse_pockets_of_interest(pockets_ratio_file)

        chain1_features_ratio = \
        evalResults(chain1_features_ratio, features, pockets_ratio, cutoff_ratio)
        
        chain1_features_count = \
        evalResults(chain1_features_count, features, pockets_count, cutoff_count)

        pockets_of_interest_file = './' + currMutation + '/fpocketResults/' + run + '_chain2.txt'
        pockets_ratio_file = './' + currMutation + '/fpocketResults/Ratio_' + run + '_chain2.txt'

        # Parsing files
        pockets_count, cutoff_count = parse_pockets_of_interest(pockets_of_interest_file) # {#frame: pocket}
        pockets_ratio, cutoff_ratio = parse_pockets_of_interest(pockets_ratio_file)
        
        chain2_features_ratio = \
        evalResults(chain2_features_ratio, features, pockets_ratio, cutoff_ratio)
        
        chain2_features_count = \
        evalResults(chain2_features_count, features, pockets_count, cutoff_count)

# %%
data = chain1_features_count
chain_id = '1'

# %%
len(chain1_features_count['N272H_AF']['Run1'].keys())
# Out:
# 6

# %%
allFeature = {}

for mutation in chain1_features_count.keys():
    if mutation not in allFeature.keys():
        allFeature[mutation] = {}
    for run in chain1_features_count[mutation].keys():
        if run not in allFeature[mutation].keys():
            allFeature[mutation][run] = {}
        for feature in chain1_features_count[mutation][run].keys():
            if feature not in allFeature[mutation][run].keys():
                allFeature[mutation][run][feature] = {}

            allFeature[mutation][run][feature]['1'] = chain1_features_count[mutation][run][feature]
            allFeature[mutation][run][feature]['2'] = chain2_features_count[mutation][run][feature]

# %%
data = allFeature

# Prepare DataFrame columns and data
columns = []
data_lists = []

# Process data
for mutation in data:
    for run in data[mutation]:
        for dist_key, chains in data[mutation][run].items():
            for chain_id, values in chains.items():
                col_name = f"{mutation}_{run}_{dist_key}_{chain_id}"
                columns.append(col_name)
                data_lists.append(values)  # Append the whole list, not extend

# Create DataFrame from the lists
df = pd.DataFrame(list(zip(*data_lists)), columns=columns)

# Write to Excel file
df.to_excel("AF_features.xlsx", engine='openpyxl', index=False)
